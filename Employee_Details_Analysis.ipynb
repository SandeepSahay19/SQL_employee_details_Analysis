# %% [markdown]
#    # Employee Details Analysis Using SQL Queries

# %% [markdown]
# ### Question 1

# %% [markdown]
# ![EmployeeTable.png](attachment:EmployeeTable.png)

# %% [markdown]
# ## Create Table EmployeeDetails and EmployeeSalary using SQL queries and fill the values as given in the above Table :

# %% [markdown]
# ### Solution:  Queries to create Table EmployeeDetails :-

# %% [markdown]
# #### CREATE Table EmployeeDetails (
# #### EmpId INT,
# #### FullName VARCHAR(50),
# #### ManagerId INT,
# #### DateOfJoining Date,
# #### City Varchar(50)
# #### );

# %% [markdown]
# ##  Adding values inside EmployeeDetails Tables:

# %% [markdown]
# #### Insert into EmployeeDetails( EmpId, FullName, ManagerId, DateOfJoining, City)
# #### Values
# #### ( 121 , "John Snow", 321 , "2019-01-31" , "Toronto"),
# #### ( 321 , "Walter White", 986 , "2020-01-30","California"),
# ##### ( 421 , "Kuldeep Rana", 876 , "2021-11-27", "New Delhi");

# %% [markdown]
# ![EmployeedetailsTable.png](attachment:EmployeedetailsTable.png)

# %% [markdown]
# ## Queries to create EmployeeSales Table :

# %% [markdown]
# #### Create Table EmployeeSales (
# #### EmpId INT,
# #### Project Varchar(50),
# #### Salary INT
# #### );

# %% [markdown]
# ## Queries to add vlues in EmployeeSales Table :

# %% [markdown]
# #### INSERT INTO EmployeeSalary ( EmpId, Project, Salary, Variable)
# #### Values
# #### ( 121 ,"P1", 8000, 500),
# #### ( 321 ,"P2", 10000, 1000),
# #### ( 421 ,"P3", 12000, 0);

# %% [markdown]
# ![EmployeeSalaryTable.png](attachment:EmployeeSalaryTable.png)

# %% [markdown]
# ## Question 2) _Write an SQL query to find the employee id whose salary lies in the range of 9000 and 15000_.

# %% [markdown]
# ### Solution:

# %% [markdown]
# #### SELECT EmpId, Salary
# #### FROM EmployeeSalary
# #### WHERE Salary BETWEEN 9000 AND 15000;

# %% [markdown]
# ## Question 3) _Write an SQL query to know those employees who live in California and work under the manager with ManagerId – 986._

# %% [markdown]
# ### Solution:

# %% [markdown]
# #### SELECT EmpId, City, ManagerId
# #### FROM EmployeeDetails
# #### WHERE City='Toronto' AND ManagerId='986';

# %% [markdown]
# ### _RESULT:_  ***Walter White lives in California and Works under Manager Id- 986***

# %% [markdown]
# ## Question 4) _Write an SQL query to find out all those employees who work on Projects other than P1._

# %% [markdown]
# ### Solution:

# %% [markdown]
# ### SELECT EmpId
# ### FROM EmployeeSalary
# ### WHERE NOT Project= 'P1' ;

# %% [markdown]
# ### _Result:_  ***Walter White (EmpId = 321) and Kuldeep Rana(EmpId=421) works on projects other than P1.***

# %% [markdown]
# ## Question 5) _Write an SQL query to find the maximum, minimum, and average salary of the employees._

# %% [markdown]
# ### Solution:

# %% [markdown]
# #### SELECT Max(Salary),
# #### Min(Salary),
# #### AVG(Salary)
# #### FROM EmployeeSalary;

# %% [markdown]
# ### ***Result :***    Maximum Salary is 12000,Minimum Salary is 8000 and Average Salary is 10000.
